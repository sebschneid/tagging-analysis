# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tagging import plot, data

# %%
plot.make_phase_plot_for_dataset("solin", ymin=-35, ymax=35)
plt.savefig("solin.png", bbox_inches="tight")
# Out:
# 2.8372093023255816
# 2.7126436781609193

# %%
plot.make_phase_plot_for_dataset("kustosija", file_suffix="_peak")
plt.savefig("kustosija.png", bbox_inches="tight")
# Out:
# 3.5632183908045976
# 3.4927536231884058

# %%
plot.make_phase_plot_for_dataset("dugopolje", file_suffix="_peak")
plt.savefig("dugopol.png", bbox_inches="tight")
# Out:
# 3.227272727272727
# 3.7872340425531914

# %%
plot.make_phase_plot_for_dataset("sibenik", file_suffix="_peak")
plt.savefig("sibenik.png", bbox_inches="tight")
# Out:
# 3.409090909090909
# 3.1447368421052633

# %%
plot.make_phase_plot_for_dataset("zmijavci", file_suffix="_peak")
plt.savefig("zmijavci.png", bbox_inches="tight")
# Out:
# 3.4158415841584158
# 4.193548387096774

# %%
data.duration_overview("solin")

# %%
data.duration_overview("dugopolje")

# %% [markdown]
# * Timeline mit Balken breite dauer und höhe Peak
# * rolling über 10 Minuten Passquote: `"IMM.REC`, `CAN COUNTERPRESS`, `CAN'T COUNTERPRESS`
# * Passquoten der Spieler: Erfolgreiche Pässe in Blautönen mit Packing und in Rottönen unerfolgreiche Pässe.
#     * Weiß: Egal, Blau: Erfolgreich, Rot: Unerfolgreich
# * In welchen Phasen sind Schüsse aufgetreten
# * Packing Peaks:
#     - grün, weiß, gelb, orange, rot
