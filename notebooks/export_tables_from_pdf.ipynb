# %%
import pandas as pd

import camelot
import matplotlib.pyplot as plt

# %%
pages = ','.join([str(entry) for entry in list(range(1, 5))])

# %%
areas_for_pages = {
    "1": ['0,800,500,300', '0,300,500,0'],
    "2": ['0,800,500,590', '0,590,500,0'],
    "3": ['0,800,500,360', '0,360,500,0'],
    "4": ['100,800,340,700', '340,800,500,700', '100,700,380,600', '380,700,500,600',  '100,600,400,0'],
}

# %%
page = "2"
tables = camelot.read_pdf('../data/Hajduk-2-vs-Rudeš-stats.pdf', flavor="stream", pages=page, table_areas=areas_for_pages[page])
tables
# Out:
# <TableList n=2>

# %%
for table in tables:
    camelot.plot(table, kind='contour')
    plt.show()

# %%
table = tables[0]

# %%
pd.DataFrame(table.data[2:], columns=table.data[1]).set_index('')
# Out:
#                  FAIL   0   1  2  3 4+ TOTAL     %
#
# Davor Matijaš       2  23   1  1  0  1    28    93
# Vice Baždarić       0   0   0  0  0  0     0     0
# Stipe Radić         6  70   7  7  3  3    96    94
# Ivica Batarelo      3  58   6  4  2  2    75    96
# Lumbardh Delova     0   0   0  0  0  0     0     0
# Mario Vušković      0   0   0  0  0  0     0     0
# Hrvoje Relota       7  43  11  3  1  0    65    89
# Josip Ciprić        0   0   0  0  0  0     0     0
# Vicko Ševelj        7  37  10  8  1  1    64    89
# Marko Martinović    0   0   0  0  0  0     0     0
# Dino Skorup         7  31   8  8  5  0    59    88
# Filip Kosić         3   8   3  0  1  0    15    80
# Ivan Giljanović     0   0   0  0  0  0     0     0
# Jurica Pršir       16  31   2  3  1  0    53    70
# Luka Grubišić       0   0   0  0  0  0     0     0
# Emir Sahiti         0   0   0  0  0  0     0     0
# Jurica Bajić        7  13   3  1  2  0    26    73
# ...

# %%
tables[3].df
# Out:
#                    0  1   2   3   4  5   6
# 0      Davor Matijaš  0   0   0   0  0   0
# 1      Vice Baždarić  0   0   0   0  0   0
# 2        Stipe Radić  2   2   4  20  7  27
# 3     Ivica Batarelo  1   2   3  12  4  16
# 4    Lumbardh Delova  0   0   0   0  0   0
# 5     Mario Vušković  0   0   0   0  0   0
# 6      Hrvoje Relota  5   7  12  15  7  22
# 7       Josip Ciprić  0   0   0   0  0   0
# 8       Vicko Ševelj  2   4   6  23  9  32
# 9   Marko Martinović  0   0   0   0  0   0
# 10       Dino Skorup  5  11  16   9  4  13
# 11       Filip Kosić  0   0   0   3  1   4
# 12   Ivan Giljanović  0   0   0   0  0   0
# 13      Jurica Pršir  4   8  12  14  6  20
# 14     Luka Grubišić  0   0   0   0  0   0
